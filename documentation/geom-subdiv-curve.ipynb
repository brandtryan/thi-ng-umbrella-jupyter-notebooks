// %%
// Tangled @ 2025-07-07T23:19:30-04:00 - DO NOT EDIT!
// Source: /home/brandt/Projects/Repos/umbrella/packages/geom-subdiv-curve/src/kernels.ts

import { subdivide, SUBDIV_DISPLACE } from "@thi.ng/geom-subdiv-curve";

// define subdiv kernel w/ custom displacements
const kernel = SUBDIV_DISPLACE([[0.25, 0.25], [0.75, -0.25]]);

// subdivide polyline with the kernel
console.log(
	subdivide([[0, 0], [100, 100], [200, 0]], kernel)
);
// [
//   [ 0, 0 ], [ 50, 0 ], [ 50, 100 ], [ 100, 100 ],
//   [100, 50 ], [ 200, 50 ], [ 200, 0 ]
// ]
// Out:
// Stack trace:
// TypeError: kernels is not iterable
//     at subdivide (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/geom-subdiv-curve/subdivide.js:7:33)
//     at <anonymous>:16:13

// %%
// Tangled @ 2025-07-07T23:19:22-04:00 - DO NOT EDIT!
// Source: /home/brandt/Projects/Repos/umbrella/packages/geom/src/subdiv-curve.ts

import { asSvg, rect, subdivCurve, SUBDIV_CHAIKIN_CLOSED } from "@thi.ng/geom";

console.log(
	asSvg(subdivCurve(rect(100), SUBDIV_CHAIKIN_CLOSED))
);
// <polygon points="0,25 25,0 75,0 100,25 100,75 75,100 25,100 0,75"/>
// Out:
// Stack trace:
// TypeError: Cannot destructure property 'fn' of '.for' as it is undefined.
//     at subdivide (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/geom-subdiv-curve/subdivide.js:7:14)
//     at file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/geom/subdiv-curve.js:44:19
//     at Polygon.copyTransformed (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/geom/api/polygon.js:13:39)
//     at poly (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/geom/subdiv-curve.js:43:34)
//     at fn (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/defmulti/defmulti.js:10:16)
//     at $aspoly (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/geom/subdiv-curve.js:36:39)
//     at fn (file:///home/brandt/Projects/Repos/thi-ng-umbrella-jupyter-notebooks/packages/defmulti/defmulti.js:10:16)
//     at <anonymous>:4:19
